# %%
import pandas as pd
import numpy as np

class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
df1 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/A2M.AX.csv")
df2 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AAD.AX.csv")
df3 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ABC.AX.csv")
df4 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ABP.AX.csv")
df5 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AGL.AX.csv")
df6 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AHG.AX.csv")
df7 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ALL.AX.csv")
df8 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ALQ.AX.csv")
df9 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ALU.AX.csv")
df10 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ALX.AX.csv")
df11 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AMC.AX.csv")
df12 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AMP.AX.csv")
df13 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ANN.AX.csv")
df14 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ANZ.AX.csv")
df15 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AOG.AX.csv")
df16 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/APA.AX.csv")
df17 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/API.AX.csv")
df18 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/APO.AX.csv")
df19 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/APT.AX.csv")
df20 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ARB.AX.csv")
df21 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ASL.AX.csv")
df22 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AST.AX.csv")
df23 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ASX.AX.csv")
df24 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AWC.AX.csv")
df25 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/AZJ.AX.csv")
df26 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BAL.AX.csv")
df27 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BAP.AX.csv")
df28 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BEN.AX.csv")
df29 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BGA.AX.csv")
df30 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BHP.AX.csv")
df31 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BKL.AX.csv")
df32 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BKW.AX.csv")
df33 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BLD.AX.csv")
df34 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BOQ.AX.csv")
df35 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BPT.AX.csv")
df36 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BRG.AX.csv")
df37 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BSL.AX.csv")
df38 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BWP.AX.csv")
df39 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/BXB.AX.csv")
df40 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CAR.AX.csv")
df41 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CBA.AX.csv")
df42 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CCL.AX.csv")
df43 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CCP.AX.csv")
df44 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CGF.AX.csv")
df45 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CHC.AX.csv")
df46 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CIM.AX.csv")
df47 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CLW.AX.csv")
df48 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CMW.AX.csv")
df49 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CNU.AX.csv")
df50 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/COH.AX.csv")
df51 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CPU.AX.csv")
df52 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CQR.AX.csv")
df53 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CSL.AX.csv")
df54 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CSR.AX.csv")
df55 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CTD.AX.csv")
df56 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CTX.AX.csv")
df57 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CWN.AX.csv")
df58 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CWY.AX.csv")
df59 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CYB.AX.csv")
df60 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/DHG.AX.csv")
df61 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/DLX.AX.csv")
df62 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/DMP.AX.csv")
df63 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/DOW.AX.csv")
df64 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/DXS.AX.csv")
df65 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ECX.AX.csv")
df66 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/EHE.AX.csv")
df67 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/EVN.AX.csv")
df68 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/FBU.AX.csv")
df69 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/FLT.AX.csv")
df70 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/FMG.AX.csv")
df71 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/FPH.AX.csv")
df72 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/FXJ.AX.csv")
df73 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GEM.AX.csv")
df74 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GMA.AX.csv")
df75 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GMG.AX.csv")
df76 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GNC.AX.csv")
df77 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GOZ.AX.csv")
df78 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GPT.AX.csv")
df79 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GTY.AX.csv")
df80 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/HSO.AX.csv")
df81 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/HVN.AX.csv")
df82 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IAG.AX.csv")
df83 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IEL.AX.csv")
df84 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IFL.AX.csv")
df85 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IFN.AX.csv")
df86 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IGO.AX.csv")
df87 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ILU.AX.csv")
df88 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ING.AX.csv")
df89 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IPH.AX.csv")
df90 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IPL.AX.csv")
df91 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IRE.AX.csv")
df92 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IVC.AX.csv")
df93 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/JBH.AX.csv")
df94 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/JHG.AX.csv")
df95 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/JHX.AX.csv")
df96 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/LLC.AX.csv")
df97 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/LNK.AX.csv")
df98 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/LYC.AX.csv")
df99 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MFG.AX.csv")
df100 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MGR.AX.csv")
df101 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MIN.AX.csv")
df102 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MMS.AX.csv")
df103 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MND.AX.csv")
df104 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MPL.AX.csv")
df105 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MQG.AX.csv")
df106 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MTS.AX.csv")
df107 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MYO.AX.csv")
df108 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MYX.AX.csv")
df109 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NAB.AX.csv")
df110 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NAN.AX.csv")
df111 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NCM.AX.csv")
df112 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NEC.AX.csv")
df113 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NHF.AX.csv")
df114 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NSR.AX.csv")
df115 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NST.AX.csv")
df116 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NUF.AX.csv")
df117 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NVT.AX.csv")
df118 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NWS.AX.csv")
df119 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NXT.AX.csv")
df120 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/OML.AX.csv")
df121 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORA.AX.csv")
df122 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORE.AX.csv")
df123 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORG.AX.csv")
df124 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORI.AX.csv")
df125 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/OSH.AX.csv")
df126 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/OZL.AX.csv")
df127 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PDL.AX.csv")
df128 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PGH.AX.csv")
df129 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PLS.AX.csv")
df130 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PMV.AX.csv")
df131 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PPT.AX.csv")
df132 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PRY.AX.csv")
df133 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PTM.AX.csv")
df134 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/QAN.AX.csv")
df135 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/QBE.AX.csv")
df136 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/REA.AX.csv")
df137 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RHC.AX.csv")
df138 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RIO.AX.csv")
df139 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RMD.AX.csv")
df140 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RRL.AX.csv")
df141 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RSG.AX.csv")
df142 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RWC.AX.csv")
df143 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/S32.AX.csv")
df144 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SAR.AX.csv")
df145 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SBM.AX.csv")
df146 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SCG.AX.csv")
df147 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SCP.AX.csv")
df148 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SDA.AX.csv")
df149 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SDF.AX.csv")
df150 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SEK.AX.csv")
df151 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SFR.AX.csv")
df152 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SGM.AX.csv")
df153 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SGP.AX.csv")
df154 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SHL.AX.csv")
df155 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SIG.AX.csv")
df156 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SIQ.AX.csv")
df157 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SKC.AX.csv")
df158 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SKI.AX.csv")
df159 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SOL.AX.csv")
df160 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SPK.AX.csv")
df161 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SRX.AX.csv")
df162 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/STO.AX.csv")
df163 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SUL.AX.csv")
df164 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SUN.AX.csv")
df165 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SVW.AX.csv")
df166 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SWM.AX.csv")
df167 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SXL.AX.csv")
df168 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SYD.AX.csv")
df169 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SYR.AX.csv")
df170 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TAH.AX.csv")
df171 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TCL.AX.csv")
df172 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TGR.AX.csv")
df173 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TLS.AX.csv")
df174 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TME.AX.csv")
df175 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TNE.AX.csv")
df176 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TPM.AX.csv")
df177 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/TWE.AX.csv")
df178 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/URW.AX.csv")
df179 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/VCX.AX.csv")
df180 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/VOC.AX.csv")
df181 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/VVR.AX.csv")
df182 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WBC.AX.csv")
df183 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WEB.AX.csv")
df184 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WES.AX.csv")
df185 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WHC.AX.csv")
df186 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WOR.AX.csv")
df187 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WOW.AX.csv")
df188 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WPL.AX.csv")
df189 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WSA.AX.csv")
df190 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/WTC.AX.csv")
df191 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/XRO.AX.csv")
df192 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/APX.AX.csv")
df193 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/CGC.AX.csv")
df194 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GUD.AX.csv")
df195 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GWA.AX.csv")
df196 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GXL.AX.csv")
df197 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/GXY.AX.csv")
df198 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/SGR.AX.csv")
df199 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/QUB.AX.csv")





finaldf = pd.concat([df1, df2, df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,df51,df52,df53,df54,df55,df56,df57,df58,df59,df60,
                    df61,df62,df63,df64,df65,df66,df67,df68,df69,df70,df71,df72,df73,df74,df75,df76,df77,df78,df79,df80,df81,df82,df83,df84,df85,df86,df87,df88,df89,df90,df91,df92,df93,df94,df95,df96,df97,df98,df99,df100,df101, df102,df103,df104,df105,df106,df107,df108,df109,df110,df111,df112,df113,df114,df115,df116,df117,df118,df119,df120,df121,df122,df123,df124,df125,df126,df127,df128,df129,df130,df131,df132,df133,df134,df135,df136,df137,df138,df139,df140,df141,df142,df143,df144,df145,df146,df147,df148,df149,df150,df151,df152,df153,df154,df155,df156,df157,df158,df159,df160,
                    df161,df162,df163,df164,df165,df166,df167,df168,df169,df170,df171,df172,df173,df174,df175,df176,df177,df178,df179,df180,df181,df182,df183,df184,df185,df186,df187,df188,df189,df190,df191,df192,df193,df194,df195,df196,df197,df98,df199],axis=0,join='inner')



finaldf.to_csv( "combined_csv.csv", index=True )
