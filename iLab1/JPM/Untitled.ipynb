# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/A2M.AX.csv")
df2 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AAD.AX.csv")
df3 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ABC.AX.csv")
df4 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ABP.AX.csv")
df5 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AGL.AX.csv")
df6 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AHG.AX.csv")
df7 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ALL.AX.csv")
df8 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ALQ.AX.csv")
df9 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ALU.AX.csv")
df10 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ALX.AX.csv")
df11 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AMC.AX.csv")
df12 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AMP.AX.csv")
df13 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ANN.AX.csv")
df14 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ANZ.AX.csv")
df15 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AOG.AX.csv")
df16 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/APA.AX.csv")
df17 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/API.AX.csv")
df18 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/APO.AX.csv")
df19 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/APT.AX.csv")
df20 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ARB.AX.csv")
df21 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ASL.AX.csv")
df22 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AST.AX.csv")
df23 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ASX.AX.csv")
df24 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AWC.AX.csv")
df25 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/AZJ.AX.csv")
df26 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BAL.AX.csv")
df27 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BAP.AX.csv")
df28 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BEN.AX.csv")
df29 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BGA.AX.csv")
df30 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BHP.AX.csv")
df31 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BKL.AX.csv")
df32 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BKW.AX.csv")
df33 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BLD.AX.csv")
df34 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BOQ.AX.csv")
df35 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BPT.AX.csv")
df36 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BRG.AX.csv")
df37 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BSL.AX.csv")
df38 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BWP.AX.csv")
df39 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/BXB.AX.csv")
df40 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CAR.AX.csv")
df41 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CBA.AX.csv")
df42 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CCL.AX.csv")
df43 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CCP.AX.csv")
df44 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CGF.AX.csv")
df45 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CHC.AX.csv")
df46 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CIM.AX.csv")
df47 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CLW.AX.csv")
df48 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CMW.AX.csv")
df49 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CNU.AX.csv")
df50 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/COH.AX.csv")
df51 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CPU.AX.csv")
df52 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CQR.AX.csv")
df53 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CSL.AX.csv")
df54 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CSR.AX.csv")
df55 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CTD.AX.csv")
df56 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CTX.AX.csv")
df57 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CWN.AX.csv")
df58 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CWY.AX.csv")
df59 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/CYB.AX.csv")
df60 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/DHG.AX.csv")
df61 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/DLX.AX.csv")
df62 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/DMP.AX.csv")
df63 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/DOW.AX.csv")
df64 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/DXS.AX.csv")
df65 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/ECX.AX.csv")
df66 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/EHE.AX.csv")
df67 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/EVN.AX.csv")
df68 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/FBU.AX.csv")
df69 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/FLT.AX.csv")
df70 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/FMG.AX.csv")
df71 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/FPH.AX.csv")
df72 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/FXJ.AX.csv")
df73 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/GEM.AX.csv")
df74 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/GMA.AX.csv")
df75 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/GMG.AX.csv")
df76 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/GNC.AX.csv")
df77 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/GOZ.AX.csv")
df78 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/GPT.AX.csv")
df79 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/GTY.AX.csv")
df80 = pd.read_csv("/Users/ujash/Documents/IlabDatasets/Top200Companies/HSO.AX.csv")
df81 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/HVN.AX.csv")
df82 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IAG.AX.csv")
df83 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IEL.AX.csv")
df84 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IFL.AX.csv")
df85 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IFN.AX.csv")
df86 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IGO.AX.csv")
df87 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ILU.AX.csv")
df88 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ING.AX.csv")
df89 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IPH.AX.csv")
df90 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IPL.AX.csv")
df91 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IRE.AX.csv")
df92 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/IVC.AX.csv")
df93 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/JBH.AX.csv")
df94 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/JHG.AX.csv")
df95 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/JHX.AX.csv")
df96 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/LLC.AX.csv")
df97 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/LNK.AX.csv")
df98 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/LYC.AX.csv")
df99 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MFG.AX.csv")
df100 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MGR.AX.csv")
df101 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MIN.AX.csv")
df102 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MMS.AX.csv")
df103 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MND.AX.csv")
df104 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MPL.AX.csv")
df105 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MQG.AX.csv")
df106 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MTS.AX.csv")
df107 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MYO.AX.csv")
df108 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/MYX.AX.csv")
df109 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NAB.AX.csv")
df110 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NAN.AX.csv")
df111 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NCM.AX.csv")
df112 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NEC.AX.csv")
df113 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NHF.AX.csv")
df114 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NSR.AX.csv")
df115 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NST.AX.csv")
df116 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NUF.AX.csv")
df117 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NVT.AX.csv")
df118 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NWS.AX.csv")
df119 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/NXT.AX.csv")
df120 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/OML.AX.csv")
df121 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORA.AX.csv")
df122 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORE.AX.csv")
df123 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORG.AX.csv")
df124 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/ORI.AX.csv")
df125 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/OSH.AX.csv")
df126 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/OZL.AX.csv")
df127 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PDL.AX.csv")
df128 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PGH.AX.csv")
df129 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PLS.AX.csv")
df130 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PMV.AX.csv")
df131 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PPT.AX.csv")
df132 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PRY.AX.csv")
df133 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/PTM.AX.csv")
df134 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/QAN.AX.csv")
df135 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/QBE.AX.csv")
df136 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/REA.AX.csv")
df137 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RHC.AX.csv")
df138 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RIO.AX.csv")
df139 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RMD.AX.csv")
df140 = pd.read_csv(r"/Users/ujash/Documents/IlabDatasets/Top200Companies/RRL.AX.csv")





finaldf = pd.concat([df1, df2, df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,df51,df52,df53,df54,df55,df56,df57,df58,df59,df60],join='inner')


finaldf.to_csv( "combined_csv5.csv", index=True)
